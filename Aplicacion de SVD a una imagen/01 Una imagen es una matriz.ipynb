# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
plt.style.use('classic')

imagen = Image.open("..\imagenes\imagen_1.jpg")

plt.imshow(imagen)

# %%
imagen_gr = imagen.convert('LA')

# %%
print(imagen_gr)
# Out:
# <PIL.Image.Image image mode=LA size=720x720 at 0x19135863A88>

# %%
imagen_mat = np.array(list(imagen_gr.getdata(band=0)), float)
print(imagen_mat)
# Out:
# [250. 250. 250. ... 250. 250. 250.]

# %%
imagen_mat.shape = (imagen_gr.size[1], imagen_gr.size[0])
print(imagen_mat)
# Out:
# [[250. 250. 250. ... 250. 250. 250.]
#  [250. 250. 250. ... 250. 250. 250.]
#  [250. 250. 250. ... 250. 250. 250.]
#  ...
#  [250. 250. 250. ... 250. 250. 250.]
#  [250. 250. 250. ... 250. 250. 250.]
#  [250. 250. 250. ... 250. 250. 250.]]

# %%
print(imagen_mat.shape)
# Out:
# (720, 720)

# %%
plt.imshow(imagen_mat, cmap  = 'gray')
plt.show()

# %%
imagen_mat_2 = imagen_mat / 10
print(imagen_mat_2)
# Out:
# [[25. 25. 25. ... 25. 25. 25.]
#  [25. 25. 25. ... 25. 25. 25.]
#  [25. 25. 25. ... 25. 25. 25.]
#  ...
#  [25. 25. 25. ... 25. 25. 25.]
#  [25. 25. 25. ... 25. 25. 25.]
#  [25. 25. 25. ... 25. 25. 25.]]

# %%
plt.imshow(imagen_mat_2, cmap = 'gray')
plt.show()

# %%
print(np.max(imagen_mat_2))
print(np.max(imagen_mat))
# Out:
# 25.4
# 254.0

# %%
print(np.min(imagen_mat_2))
print(np.min(imagen_mat))
# Out:
# 0.2
# 2.0
